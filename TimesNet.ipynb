# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from neuralforecast.core import NeuralForecast
from neuralforecast.models import NHITS, NBEATS, TimesNet

from neuralforecast.losses.numpy import mae, mse

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('data/etth1.csv')

df['ds'] = pd.to_datetime(df['ds'])

df.head()
# Out:
#                    ds unique_id         y
# 0 2016-07-01 00:00:00        OT  1.460552
# 1 2016-07-01 01:00:00        OT  1.161527
# 2 2016-07-01 02:00:00        OT  1.161527
# 3 2016-07-01 03:00:00        OT  0.862611
# 4 2016-07-01 04:00:00        OT  0.525227

# %%
fig, ax = plt.subplots()

ax.plot(df['y'])
ax.set_xlabel('Time')
ax.set_ylabel('Oil temperature')

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# ## Model

# %%
horizon = 96

models = [NHITS(h=horizon,
               input_size=2*horizon,
               max_steps=50),
         NBEATS(h=horizon,
               input_size=2*horizon,
               max_steps=50),
         TimesNet(h=horizon,
                 input_size=2*horizon,
                 max_steps=50)]
# Out:
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1

# %%
nf = NeuralForecast(models=models, freq='H')

# %%
preds_df = nf.cross_validation(df=df, step_size=horizon, n_windows=2)
# Out:
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  8.26it/s, v_num=71, train_loss_step=0.251, train_loss_epoch=0.258]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                   | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  7.19it/s, v_num=71, train_loss_step=0.251, train_loss_epoch=0.258]
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  6.89it/s, v_num=71, train_loss_step=0.251, train_loss_epoch=0.251]
# Predicting DataLoader 0: 100%|██████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 166.63it/s]
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  7.46it/s, v_num=73, train_loss_step=0.252, train_loss_epoch=0.259]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                   | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  6.62it/s, v_num=73, train_loss_step=0.252, train_loss_epoch=0.259]
# Epoch 49: 100%|█████████████████| 1/1 [00:00<00:00,  6.21it/s, v_num=73, train_loss_step=0.252, train_loss_epoch=0.252]
# Predicting DataLoader 0: 100%|██████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 125.02it/s]
# Epoch 49: 100%|█████████████████| 1/1 [00:10<00:00, 10.90s/it, v_num=75, train_loss_step=1.090, train_loss_epoch=1.160]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                   | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█████████████████| 1/1 [00:10<00:00, 10.92s/it, v_num=75, train_loss_step=1.090, train_loss_epoch=1.160]
# Epoch 49: 100%|█████████████████| 1/1 [00:10<00:00, 10.93s/it, v_num=75, train_loss_step=1.090, train_loss_epoch=1.090]
# Predicting DataLoader 0: 100%|███████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.88it/s]

# %%
preds_df.head()
# Out:
#   unique_id                  ds              cutoff     NHITS    NBEATS  \
# 0        OT 2018-02-13 00:00:00 2018-02-12 23:00:00 -1.410976 -1.411055
# 1        OT 2018-02-13 01:00:00 2018-02-12 23:00:00 -1.420605 -1.390586
# 2        OT 2018-02-13 02:00:00 2018-02-12 23:00:00 -1.432935 -1.436199
# 3        OT 2018-02-13 03:00:00 2018-02-12 23:00:00 -1.443960 -1.463686
# 4        OT 2018-02-13 04:00:00 2018-02-12 23:00:00 -1.461759 -1.468359
#
#    TimesNet         y
# 0 -1.511951 -1.398929
# 1 -1.539502 -1.398929
# 2 -1.516600 -1.421923
# 3 -1.541980 -1.506269
# 4 -1.508051 -1.452545

# %%
fig, ax = plt.subplots()

ax.plot(preds_df['y'], label='actual')
ax.plot(preds_df['NHITS'], label='N-HITS', ls='--')
ax.plot(preds_df['NBEATS'], label='N-BEATS', ls=':')
ax.plot(preds_df['TimesNet'], label='TimesNet', ls='-.')

ax.legend(loc='best')
ax.set_xlabel('Time steps')
ax.set_ylabel('Oil temperature')

fig.autofmt_xdate()
plt.tight_layout()

# %%
data = {'N-HiTS': [mae(preds_df['NHITS'], preds_df['y']), mse(preds_df['NHITS'], preds_df['y'])],
       'N-BEATS': [mae(preds_df['NBEATS'], preds_df['y']), mse(preds_df['NBEATS'], preds_df['y'])],
       'TimesNet': [mae(preds_df['TimesNet'], preds_df['y']), mse(preds_df['TimesNet'], preds_df['y'])]}

metrics_df = pd.DataFrame(data=data)
metrics_df.index = ['mae', 'mse']

metrics_df.style.highlight_min(color='lightgreen', axis=1)
# Out:
# <style type="text/css">
# #T_1fdc9_row0_col0, #T_1fdc9_row1_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1fdc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fdc9_level0_col0" class="col_heading level0 col0" >N-HiTS</th>
#       <th id="T_1fdc9_level0_col1" class="col_heading level0 col1" >N-BEATS</th>
#       <th id="T_1fdc9_level0_col2" class="col_heading level0 col2" >TimesNet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fdc9_level0_row0" class="row_heading level0 row0" >mae</th>
#       <td id="T_1fdc9_row0_col0" class="data row0 col0" >0.180884</td>
#       <td id="T_1fdc9_row0_col1" class="data row0 col1" >0.182920</td>
#       <td id="T_1fdc9_row0_col2" class="data row0 col2" >0.187393</td>
#     </tr>
#     <tr>
#       <th id="T_1fdc9_level0_row1" class="row_heading level0 row1" >mse</th>
#       <td id="T_1fdc9_row1_col0" class="data row1 col0" >0.049666</td>
#       <td id="T_1fdc9_row1_col1" class="data row1 col1" >0.049415</td>
#       <td id="T_1fdc9_row1_col2" class="data row1 col2" >0.056594</td>
#     </tr>
#   </tbody>
# </table>
